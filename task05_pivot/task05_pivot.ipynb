# %%
import pandas as pd
df = pd.read_csv('../task04_merge/merged_full_data.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0_x campaign_id_x   channel   budget  Unnamed: 0_y customer_id  \
# 0             0        CMP100  Facebook  8000000            69     CUS1069
# 1             0        CMP100  Facebook  8000000            87     CUS1087
# 2             0        CMP100  Facebook  8000000            87     CUS1087
# 3             0        CMP100  Facebook  8000000            99     CUS1099
# 4             0        CMP100  Facebook  8000000            99     CUS1099
# 5             0        CMP100  Facebook  8000000           117     CUS1117
# 6             0        CMP100  Facebook  8000000           117     CUS1117
# 7             1        CMP101    TikTok  5000000             2     CUS1002
# 8             1        CMP101    TikTok  5000000            11     CUS1011
# 9             1        CMP101    TikTok  5000000            11     CUS1011
#
#   response  Unnamed: 0 campaign_id_y  converted    amount
# 0    Click         NaN           NaN        NaN       NaN
# ...
