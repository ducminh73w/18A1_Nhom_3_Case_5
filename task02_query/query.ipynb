# %%
import pandas as pd
df_campaign = pd.read_csv('../data_clean/campaign_clean_info.csv')
df_response = pd.read_csv('../data_clean/customer_response_clean.csv')
df_sales = pd.read_csv('../data_clean/sales_conversion_clean.csv')

# %% [markdown]
# 1. Thống kê số khách hàng phản hồi theo từng chiến dịch

# %%
print("--- BẮT ĐẦU NHIỆM VỤ 2 ---")
print("\n1. Số lượng phản hồi theo từng chiến dịch:")
response_counts = df_response['campaign_id'].value_counts()
print(response_counts)
top_5_campaigns = response_counts.iloc[:5]
print("\nTop 5 chiến dịch có phản hồi cao nhất:")
print(top_5_campaigns)
# Out:
# --- BẮT ĐẦU NHIỆM VỤ 2 ---
#
# 1. Số lượng phản hồi theo từng chiến dịch:
# campaign_id
# CMP104    11
# CMP108     9
# CMP102     9
# CMP106     8
# CMP114     8
# CMP111     7
# CMP109     7
# CMP118     7
# CMP103     7
# CMP116     6
# CMP112     5
# CMP101     5
# CMP113     5
# CMP119     5
# CMP107     4
# CMP110     4
# CMP100     4
# CMP117     4
# CMP115     3
# CMP105     2
# Name: count, dtype: int64
#
# Top 5 chiến dịch có phản hồi cao nhất:
# campaign_id
# CMP104    11
# CMP108     9
# CMP102     9
# CMP106     8
# CMP114     8
# Name: count, dtype: int64

# %% [markdown]
# 2. Tìm các chiến dịch không có phản hồi

# %%
mask_no_response = ~df_campaign['campaign_id'].isin(df_response['campaign_id'])
campaigns_no_response = df_campaign.loc[mask_no_response]

print(f"\n2. Các chiến dịch không có phản hồi:")
if campaigns_no_response.empty:
    print("Tất cả chiến dịch đều có phản hồi.")
else:
    print(campaigns_no_response[['campaign_id', 'channel']])
# Out:
# 2. Các chiến dịch không có phản hồi:
# Tất cả chiến dịch đều có phản hồi.

# %% [markdown]
# 3. Thống kê tỷ lệ Click / View / Ignore

# %%
print("\n3. Tỷ lệ các loại phản hồi:")
response_rates = df_response['response'].value_counts(normalize=True) * 100
print(response_rates)
clicks_only = df_response.loc[df_response['response'] == 'Click']
print(f"Tổng số lượt Click chi tiết: {len(clicks_only)}")
# Out:
# 3. Tỷ lệ các loại phản hồi:
# response
# Ignore    40.0
# Click     30.0
# View      30.0
# Name: proportion, dtype: float64
# Tổng số lượt Click chi tiết: 36

# %% [markdown]
# 4. Tính chuyển đổi trung bình của từng chiến dịch

# %%
avg_conversion = df_sales.groupby('campaign_id')['converted'].mean()
print("\n4. Tỷ lệ chuyển đổi trung bình theo từng chiến dịch:")
print(avg_conversion)
# Out:
# 4. Tỷ lệ chuyển đổi trung bình theo từng chiến dịch:
# campaign_id
# CMP100    0.800000
# CMP101    0.000000
# CMP102    0.857143
# CMP103    0.375000
# CMP104    0.714286
# CMP105    1.000000
# CMP106    0.625000
# CMP107    0.500000
# CMP108    0.333333
# CMP109    0.714286
# CMP110    0.000000
# CMP111    0.800000
# CMP112    0.250000
# CMP113    0.000000
# CMP114    0.444444
# CMP115    0.500000
# CMP116    0.666667
# CMP117    1.000000
# CMP118    0.875000
# CMP119    1.000000
# Name: converted, dtype: float64

# %% [markdown]
# 5. Tìm khách hàng có phản hồi nhưng không có dữ liệu chuyển đổi

# %%
customers_with_sales_data = df_sales['customer_id'].unique()
mask_missing_conversion = ~df_response['customer_id'].isin(customers_with_sales_data)
customers_no_conversion_data = df_response.loc[mask_missing_conversion]

print(f"\n5. Số lượng khách phản hồi nhưng thiếu dữ liệu chuyển đổi: {len(customers_no_conversion_data)}")
print("Danh sách 5 dòng đầu tiên:")
print(customers_no_conversion_data)
# Out:
# 5. Số lượng khách phản hồi nhưng thiếu dữ liệu chuyển đổi: 44
# Danh sách 5 dòng đầu tiên:
#      Unnamed: 0 customer_id campaign_id response
# 3             3     CUS1003      CMP107     View
# 4             4     CUS1004      CMP109     View
# 6             6     CUS1006      CMP115     View
# 7             7     CUS1007      CMP116    Click
# 10           10     CUS1010      CMP111     View
# 14           14     CUS1014      CMP103   Ignore
# 16           16     CUS1016      CMP101    Click
# 17           17     CUS1017      CMP108   Ignore
# 18           18     CUS1018      CMP102    Click
# 19           19     CUS1019      CMP103     View
# 22           22     CUS1022      CMP111   Ignore
# 23           23     CUS1023      CMP119   Ignore
# 24           24     CUS1024      CMP113     View
# 26           26     CUS1026      CMP106     View
# 28           28     CUS1028      CMP111     View
# 30           30     CUS1030      CMP117     View
# 32           32     CUS1032      CMP109   Ignore
# 33           33     CUS1033      CMP118   Ignore
# 36           36     CUS1036      CMP113    Click
# 41           41     CUS1041      CMP110     View
# 42           42     CUS1042      CMP112    Click
# 43           43     CUS1043      CMP104     View
# 44           44     CUS1044      CMP108   Ignore
# 52           52     CUS1052      CMP118    Click
# 54           54     CUS1054      CMP114   Ignore
# 60           60     CUS1060      CMP109   Ignore
# 62           62     CUS1062      CMP104     View
# 69           69     CUS1069      CMP100    Click
# 71           71     CUS1071      CMP104   Ignore
# 72           72     CUS1072      CMP109     View
# 73           73     CUS1073      CMP108    Click
# 76           76     CUS1076      CMP105    Click
# 77           77     CUS1077      CMP112   Ignore
# 79           79     CUS1079      CMP107    Click
# 84           84     CUS1084      CMP118     View
# 85           85     CUS1085      CMP116   Ignore
# 88           88     CUS1088      CMP110    Click
# 92           92     CUS1092      CMP112    Click
# 93           93     CUS1093      CMP103    Click
# 96           96     CUS1096      CMP112     View
# 101         101     CUS1101      CMP111   Ignore
# 104         104     CUS1104      CMP119   Ignore
# 105         105     CUS1105      CMP114     View
# 111         111     CUS1111      CMP104     View
